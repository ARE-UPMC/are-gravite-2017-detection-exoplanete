# %%
# %matplotlib notebook
from math import cos
from pylab import *
figure(figsize=(12,8), dpi=80)
ax=plt.axes(xlim=(0, 40), ylim=(-150, 150))
plt.ylabel('vitesse en km/h')
plt.xlabel('temps en jour')
def vitesseradiale(v0,w,T,b):
    LR=[]
    i=0
    while i<20:
        LR.append(v0*w*cos((2*3.14*i/T)+b))
        i=i+0.5
    plot(range(0,4*T),LR, color="green",  linewidth=2, linestyle="-", label="vitesse radiale")
    legend(loc='lower left')
    show()
vitesseradiale(5.9,17.95,10,-1.6)
# Out:
# <img src="data:image/png;base64,...">

# %%
from pylab import *
# %matplotlib inline
figure(figsize=(12,8), dpi=80)
ax=plt.axes(xlim=(0, 8), ylim=(0, 115))
plt.ylabel('vitesse en km/h')
plt.xlabel('temps en jour')
def vitesseradiale(v0,w,T,b):
    LR=[]
    i=0
    while i<4:
        LR.append(v0*w*cos((2*np.pi*i/T)+b))
        i=i+0.5
    return LR

plot(range(0,8),vitesseradiale(5.9,17.95,10,-1.6), color="green",  linewidth=2, linestyle="-", label="vitesse radiale")
plot(range(0,8),vitesseradiale(5.9,18.08,10,-1.6), color="blue",  linewidth=2, linestyle="-", label="VNa1")
plot(range(0,8),vitesseradiale(5.9,17.81,10,-1.6), color="red",  linewidth=2, linestyle="-", label="VNa2")       

legend(loc='lower right')

show()

# %%
# %matplotlib notebook
import numpy as np
from pylab import *
fig.set_size_inches(100, 100) 
ax=plt.axes(xlim=(-3, 3), ylim=(-3, 3))
def orbite(R):
    theta = linspace(0, 2*pi, 40)

    x = cos(theta)*R
    y = sin(theta)*R
    plot(x, y)

    show()
    
orbite(2)
# Out:
# <img src="data:image/png;base64,...">

# %%
from pylab import *
# %matplotlib inline
figure(figsize=(10,10), dpi=80)
def systeme_sans_exos(R):
    "distance au centre de l'étoile"
    theta = linspace(0, 2*pi, 40)
    x = cos(theta)*R
    y = sin(theta)*R
    plot(x, y, color="blue", linewidth=2.5, linestyle="-", label="orbite")
    scatter(0, 0, color="green", label="centre de masse")
    legend(loc='upper left')


    show ()
    

systeme_sans_exos(3)

# %%
from pylab import *
# %matplotlib inline
figure(figsize=(10,10), dpi=80)
ax=plt.axes(xlim=(-5, 5), ylim=(-5, 5))
plt.xlabel('exemple dess orbites avec la position à t=0')
def systeme_avec_exos(R):
    "distance au centre de l'étoile"
    theta = linspace(0, 2*pi, 40)
    
    x = cos(theta)*R
    y = sin(theta)*R
    x1 = cos(theta)*(R/4)
    y1 = sin(theta)*(R/4)
    plot(x, y, color="blue", linewidth=2.5, linestyle="-", label="orbite de la planète")
    scatter(0,0, color="green", label="centre de masse")
    scatter(0,4, color="blue")
    scatter(0,-R/4, color="red")
    plot(x1, y1, color="red", linewidth=2.5, linestyle="-", label="orbite du centre de l'étoile")
    legend(loc='upper left')
    plt.show
systeme_avec_exos(4)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import animation 
from pylab import*
fig= plt.figure() 
fig.set_dpi(100) 
fig.set_size_inches(50, 50) 
ax=plt.axes(xlim=(-4, 4), ylim=(-4, 4))
patch = plt.Circle((5,-5), 0.25, fc='b', label="Exoplanete") 
patch2 = plt.Circle((0, -2), 0.15, fc='yellow', label="Soleil") 
a=scatter(0, 0, color="green",label='centre etoile')
def init(): 
     patch.center = (0, 0) 
     patch2.center = (0, 0) 
     ax.add_patch(patch) 
     ax.add_patch(patch2) 
     return patch, patch2, 

 
def animate(t): 
    x,y = patch.center 
    x = 3* np.cos(np.radians(t)) 
    y =-3* np.sin(np.radians(t)) 
    patch.center = (x,y) 
    x,y = patch2.center 
    x =-np.cos(np.radians(t)) 
    y =+np.sin(np.radians(t)) 
    patch2.center= (x,y) 
     
    return patch, patch2, 
anim = animation.FuncAnimation(fig, animate, init_func=init,frames=360,interval=20,blit=True)

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=1, ncol=2, mode="expand", borderaxespad=0, handles=[a, patch, patch2])

# %%
# %matplotlib notebook
import numpy as np
from pylab import *
def orbite(R,r):
    theta = linspace(0, 2*pi, 40)
    k=0
    while k<(pi):
        x = cos(theta)*R
        y = sin(theta)*R
        k=k+0.01
    while k>pi and k<2*pi:
        x = cos(theta)*r
        y = sin(theta)*r
        k=k+0.01
    plot(x, y)

    show()
    
orbite(2,6)
# Out:
# <img src="data:image/png;base64,...">

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import animation 
from pylab import*
fig= plt.figure() 
fig.set_dpi(100) 
fig.set_size_inches(50, 50) 
ax=plt.axes(xlim=(-6, 6), ylim=(-6, 6))
patch = plt.ellipse((5,3), 0.25, fc='b', label="Exoplanete")
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6dd1f77754c3> in <module>()
#       7 fig.set_size_inches(50, 50)
#       8 ax=plt.axes(xlim=(-6, 6), ylim=(-6, 6))
# ----> 9 patch = plt.ellipse((5,3), 0.25, fc='b', label="Exoplanete")
#
# AttributeError: 'module' object has no attribute 'ellipse'

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import animation 
from pylab import*
fig= plt.figure() 
fig.set_dpi(100) 
fig.set_size_inches(50, 50) 
plt.Circle((0, -2),0.05, color="green",label='HD 209458')
# Out:
# <img src="data:image/png;base64,...">
